# %%
# import Dependancies

import pandas as pd

# %%
movie_df = pd.read_csv("./ap_all_movie_info.csv")
movie_df.head()
# Out:
#       id    imdb_id  popularity    budget    revenue    original_title  \
# 0    277  tt0320691    6.887883  22000000   95708457        Underworld
# 1   3573  tt0116191    0.477489   6000000   22231658              Emma
# 2  38357  tt1126618    0.778440  40000000   58785180     Morning Glory
# 3    607  tt0119654    3.153414  90000000  589390539      Men in Black
# 4   1887  tt0422720    0.883222  40000000   60474340  Marie Antoinette
#
#                                                 cast  \
# 0  Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2  Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 3  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#                                             homepage          director  \
# 0  http://www.sonypictures.com/movies/underworld/...       Len Wiseman
# 1                 http://www.miramax.com/movie/emma/   Douglas McGrath
# ...

# %%
movie_df.shape
# Out:
# (2069, 31)

# %%
# show me the columns
movie_df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', 'popularity_level', 'index', 'year_film',
#        'year_ceremony', 'ceremony', 'category', 'name', 'film', 'winner'],
#       dtype='object')

# %%
# CREATE Oscar Movie DF with relevant columns to the user. 
oscar_movie_df = movie_df.drop(["id", "imdb_id", "budget", "revenue", "homepage", "profit", "index", "budget_adj", "revenue_adj", "vote_count", "vote_average", "release_date", "overview", "keywords", "year_film","film", "popularity_level", "popularity","year_ceremony", "ceremony" ],axis=1)
oscar_movie_df.head()
# Out:
#      original_title                                               cast  \
# 0        Underworld  Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1              Emma  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2     Morning Glory  Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 3      Men in Black  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Marie Antoinette  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#            director                                            tagline  \
# 0       Len Wiseman                  An immortal battle for supremacy.
# 1   Douglas McGrath                      Cupid is armed and dangerous!
# 2     Roger Michell                 Breakfast TV just got interesting.
# 3  Barry Sonnenfeld  Protecting the Earth from the scum of the univ...
# 4     Sofia Coppola                  Rumor. Scandal. Fame. Revolution.
#
#    runtime                                   genres  \
# 0      121                  Fantasy|Action|Thriller
# ...

# %%
oscar_movie_df.dtypes
# Out:
# original_title          object
# cast                    object
# director                object
# tagline                 object
# runtime                  int64
# genres                  object
# production_companies    object
# release_year             int64
# category                object
# name                    object
# winner                  object
# dtype: object

# %%
oscar_movie_df.columns
# Out:
# Index(['original_title', 'cast', 'director', 'tagline', 'runtime', 'genres',
#        'production_companies', 'release_year', 'category', 'name', 'winner'],
#       dtype='object')

# %%
oscar_movie_df.shape
# Out:
# (2069, 11)

# %%
# reorder the columns

oscar_movie_df[["original_title", "tagline", "genres", "director", "cast", "production_companies", "release_year", "runtime",  "category", "name", "winner" ]]
# Out:
#                 original_title  \
# 0                   Underworld
# 1                         Emma
# 2                Morning Glory
# 3                 Men in Black
# 4             Marie Antoinette
# ...                        ...
# 2064       Shrek Forever After
# 2065         House of the Dead
# 2066                The Switch
# 2067  X-Men Origins: Wolverine
# 2068                    Buried
#
#                                                 tagline  \
# 0                     An immortal battle for supremacy.
# 1                         Cupid is armed and dangerous!
# 2                    Breakfast TV just got interesting.
# 3     Protecting the Earth from the scum of the univ...
# 4                     Rumor. Scandal. Fame. Revolution.
# ...                                                 ...
# 2064                     It ain't Ogre... Til it's Ogre
# 2065                          You won't last the night.
# 2066         The most unexpected comedy ever conceived.
# ...

# %%
oscar_movie_df.head()
# Out:
#      original_title                                               cast  \
# 0        Underworld  Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1              Emma  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2     Morning Glory  Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 3      Men in Black  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Marie Antoinette  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#            director                                            tagline  \
# 0       Len Wiseman                  An immortal battle for supremacy.
# 1   Douglas McGrath                      Cupid is armed and dangerous!
# 2     Roger Michell                 Breakfast TV just got interesting.
# 3  Barry Sonnenfeld  Protecting the Earth from the scum of the univ...
# 4     Sofia Coppola                  Rumor. Scandal. Fame. Revolution.
#
#    runtime                                   genres  \
# 0      121                  Fantasy|Action|Thriller
# ...

# %%
oscar_movie_df.shape
# Out:
# (2069, 11)

# %%
oscar_movie_df.to_csv("ap_oscar_movie.csv", index=False)

# %%
movie_df.head()
# Out:
#       id    imdb_id  popularity    budget    revenue    original_title  \
# 0    277  tt0320691    6.887883  22000000   95708457        Underworld
# 1   3573  tt0116191    0.477489   6000000   22231658              Emma
# 2  38357  tt1126618    0.778440  40000000   58785180     Morning Glory
# 3    607  tt0119654    3.153414  90000000  589390539      Men in Black
# 4   1887  tt0422720    0.883222  40000000   60474340  Marie Antoinette
#
#                                                 cast  \
# 0  Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2  Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 3  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#                                             homepage          director  \
# 0  http://www.sonypictures.com/movies/underworld/...       Len Wiseman
# 1                 http://www.miramax.com/movie/emma/   Douglas McGrath
# ...

# %%
movie_df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', 'popularity_level', 'index', 'year_film',
#        'year_ceremony', 'ceremony', 'category', 'name', 'film', 'winner'],
#       dtype='object')

# %%
# Create MONEY dataframe: 
movie_money_df = movie_df[["original_title", "tagline", "budget_adj", "revenue_adj", "profit", "director", "production_companies", "genres", "category", "runtime", "release_year", "name", "winner"]]
movie_money_df
# Out:
#                 original_title  \
# 0                   Underworld
# 1                         Emma
# 2                Morning Glory
# 3                 Men in Black
# 4             Marie Antoinette
# ...                        ...
# 2064       Shrek Forever After
# 2065         House of the Dead
# 2066                The Switch
# 2067  X-Men Origins: Wolverine
# 2068                    Buried
#
#                                                 tagline    budget_adj  \
# 0                     An immortal battle for supremacy.  2.607776e+07
# 1                         Cupid is armed and dangerous!  8.341300e+06
# 2                    Breakfast TV just got interesting.  4.000000e+07
# 3     Protecting the Earth from the scum of the univ...  1.222614e+08
# 4                     Rumor. Scandal. Fame. Revolution.  4.326677e+07
# ...                                                 ...           ...
# 2064                     It ain't Ogre... Til it's Ogre  1.650000e+08
# ...

# %%
movie_money_df.dtypes
# Out:
# original_title           object
# tagline                  object
# budget_adj              float64
# revenue_adj             float64
# profit                  float64
# director                 object
# production_companies     object
# genres                   object
# category                 object
# runtime                   int64
# release_year              int64
# name                     object
# winner                   object
# dtype: object

# %%
movie_money_df.loc[:, "budget_adj"] = '$' + movie_money_df["budget_adj"].map('{:,.0f}'.format)
movie_money_df
# Out:
# C:\Users\amr_a\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                 original_title  \
# 0                   Underworld
# 1                         Emma
# 2                Morning Glory
# 3                 Men in Black
# 4             Marie Antoinette
# ...                        ...
# 2064       Shrek Forever After
# 2065         House of the Dead
# 2066                The Switch
# 2067  X-Men Origins: Wolverine
# 2068                    Buried
#
#                                                 tagline    budget_adj  \
# 0                     An immortal battle for supremacy.   $26,077,758
# ...

# %%
movie_money_df.loc[:, "revenue_adj"] = '$' + movie_money_df["revenue_adj"].map('{:,.0f}'.format)
movie_money_df
# Out:
# C:\Users\amr_a\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                 original_title  \
# 0                   Underworld
# 1                         Emma
# 2                Morning Glory
# 3                 Men in Black
# 4             Marie Antoinette
# ...                        ...
# 2064       Shrek Forever After
# 2065         House of the Dead
# 2066                The Switch
# 2067  X-Men Origins: Wolverine
# 2068                    Buried
#
#                                                 tagline    budget_adj  \
# 0                     An immortal battle for supremacy.   $26,077,758
# ...

# %%
movie_money_df.loc[:, "profit"] = '$' + movie_money_df["profit"].map('{:,.0f}'.format)
movie_money_df
# Out:
# C:\Users\amr_a\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                 original_title  \
# 0                   Underworld
# 1                         Emma
# 2                Morning Glory
# 3                 Men in Black
# 4             Marie Antoinette
# ...                        ...
# 2064       Shrek Forever After
# 2065         House of the Dead
# 2066                The Switch
# 2067  X-Men Origins: Wolverine
# 2068                    Buried
#
#                                                 tagline    budget_adj  \
# 0                     An immortal battle for supremacy.   $26,077,758
# ...

# %%
#movie_money_df = movie_money_df.rename(columns={"original_title" : "Title", "tagline" : "Headline", "budget_adj" : "Adjusted Budget", "revenue_adj" : "Adjusted Revenue", "profit" : "Profit (Loss)", "director" : "Director", "production_companies" :"Production Company", "genres" : "Genres", "category" : "Category", "runtime" : "Lenght (Min)", "release_date" : "Release Date", "name": "Name", "winner" : "Winner"})

# %%
movie_money_df.dtypes
# Out:
# original_title          object
# tagline                 object
# budget_adj              object
# revenue_adj             object
# profit                  object
# director                object
# production_companies    object
# genres                  object
# category                object
# runtime                  int64
# release_year             int64
# name                    object
# winner                  object
# dtype: object

# %%
movie_money_df.head()
# Out:
#      original_title                                            tagline  \
# 0        Underworld                  An immortal battle for supremacy.
# 1              Emma                      Cupid is armed and dangerous!
# 2     Morning Glory                 Breakfast TV just got interesting.
# 3      Men in Black  Protecting the Earth from the scum of the univ...
# 4  Marie Antoinette                  Rumor. Scandal. Fame. Revolution.
#
#      budget_adj   revenue_adj        profit          director  \
# 0   $26,077,758  $113,448,273   $73,708,457       Len Wiseman
# 1    $8,341,300   $30,906,823   $16,231,658   Douglas McGrath
# 2   $40,000,000   $58,785,180   $18,785,180     Roger Michell
# 3  $122,261,429  $800,663,661  $499,390,539  Barry Sonnenfeld
# 4   $43,266,766   $65,413,228   $20,474,340     Sofia Coppola
#
#                                 production_companies  \
# 0  Lakeshore Entertainment|Laurinfilm|Subterranea...
# 1  Miramax Films|Haft Entertainment|Matchmaker Films
# ...

# %%
movie_money_df.shape
# Out:
# (2069, 13)

# %%
movie_money_df.to_csv("ap_movie_money.csv", index=False)
