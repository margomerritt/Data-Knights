# %%
# import dependencies
import pandas as pd
import os

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create the path and import the data
all_movie_data = os.path.join('../all_movie_info.csv')
movie_df = pd.read_csv(all_movie_data)

# %%
# View data
movie_df.head()
# Out:
#       id    imdb_id  popularity    budget    revenue    original_title  \
# 0    277  tt0320691    6.887883  22000000   95708457        Underworld
# 1   3573  tt0116191    0.477489   6000000   22231658              Emma
# 2  38357  tt1126618    0.778440  40000000   58785180     Morning Glory
# 3    607  tt0119654    3.153414  90000000  589390539      Men in Black
# 4   1887  tt0422720    0.883222  40000000   60474340  Marie Antoinette
#
#                                                 cast  \
# 0  Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2  Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 3  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#                                             homepage          director  \
# 0  http://www.sonypictures.com/movies/underworld/...       Len Wiseman
# 1                 http://www.miramax.com/movie/emma/   Douglas McGrath
# ...

# %%
# Drop unnecessary columns
clean_movie_df = movie_df.drop(columns=['id','imdb_id'])
clean_movie_df
# Out:
#       popularity     budget    revenue            original_title  \
# 0       6.887883   22000000   95708457                Underworld
# 1       0.477489    6000000   22231658                      Emma
# 2       0.778440   40000000   58785180             Morning Glory
# 3       3.153414   90000000  589390539              Men in Black
# 4       0.883222   40000000   60474340          Marie Antoinette
# ...          ...        ...        ...                       ...
# 2064    1.820934  165000000  752600867       Shrek Forever After
# 2065    0.422393    7000000   13818181         House of the Dead
# 2066    1.147365   19000000   49830607                The Switch
# 2067    0.391859  150000000  341131793  X-Men Origins: Wolverine
# 2068    0.740867    1987650   19152480                    Buried
#
#                                                    cast  \
# 0     Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1     Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# ...

# %%
# Check for null values
clean_movie_df.isnull().sum()
# Out:
# popularity                0
# budget                    0
# revenue                   0
# original_title            0
# cast                      0
# homepage                  0
# director                  0
# tagline                   0
# keywords                  0
# overview                  0
# runtime                   0
# genres                    0
# production_companies      0
# release_date              0
# vote_count                0
# vote_average              0
# release_year              0
# budget_adj                0
# revenue_adj               0
# profit                    0
# popularity_level          1
# index                   961
# year_film               961
# year_ceremony           961
# ceremony                961
# category                961
# name                    961
# film                    961
# winner                  961
# dtype: int64

# %%
# Drop rows with null values and verify removal
clean_movie_df.dropna(axis=0,how="any",inplace=True)
clean_movie_df.isnull().sum()
# Out:
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# profit                  0
# popularity_level        0
# index                   0
# year_film               0
# year_ceremony           0
# ceremony                0
# category                0
# name                    0
# film                    0
# winner                  0
# dtype: int64

# %%
# View data
clean_movie_df
# Out:
#       popularity    budget    revenue        original_title  \
# 0       6.887883  22000000   95708457            Underworld
# 1       0.477489   6000000   22231658                  Emma
# 2       0.778440  40000000   58785180         Morning Glory
# 3       3.153414  90000000  589390539          Men in Black
# 4       0.883222  40000000   60474340      Marie Antoinette
# ...          ...       ...        ...                   ...
# 1103    3.852269  25000000  377350553  Beauty and the Beast
# 1104    3.852269  25000000  377350553  Beauty and the Beast
# 1105    4.782688  45000000  788241776         The Lion King
# 1106    0.477489   6000000   22231658                  Emma
# 1107    0.477489   6000000   22231658                  Emma
#
#                                                    cast  \
# 0     Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 1     Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 2     Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# ...

# %%
# Create dataframe to hold the winners
winner_df = clean_movie_df.loc[(clean_movie_df['winner']==True)]
winner_df.head()
# Out:
#     popularity    budget   revenue      original_title  \
# 0     6.887883  22000000  95708457          Underworld
# 2     0.778440  40000000  58785180       Morning Glory
# 11    0.414629   8000000    100915   Wuthering Heights
# 18    0.928134  55000000   9450897  All the King's Men
# 20    0.928134  55000000   9450897  All the King's Men
#
#                                                  cast  \
# 0   Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 2   Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 11  Kaya Scodelario|James Northcote|Amy Wren|Nicho...
# 18  Sean Penn|Jude Law|Kate Winslet|James Gandolfi...
# 20  Sean Penn|Jude Law|Kate Winslet|James Gandolfi...
#
#                                              homepage         director  \
# 0   http://www.sonypictures.com/movies/underworld/...      Len Wiseman
# 2                   http://www.morningglorymovie.com/    Roger Michell
# 11  http://www.artificial-eye.com/film.php?cinema=...    Andrea Arnold
# ...

# %%
# Count the number of winners
num_winners = winner_df['popularity'].count()
num_winners
# Out:
# 297

# %%
# Explore popularity level column
clean_movie_df['popularity_level'].unique()
# Out:
# array(['High', 'Low', 'Medium', 'Moderately High'], dtype=object)

# %%
# Make barchart displaying the oscar winners by popularity level

# %%
# Create dataframe to hold winners with a high popularity level
winner_high_pop = winner_df.loc[(winner_df['popularity_level'] == 'High')]
winner_high_pop.head()
# Out:
#     popularity     budget     revenue original_title  \
# 0     6.887883   22000000    95708457     Underworld
# 29    4.355219  200000000  1845034188        Titanic
# 37    3.153791    3500000   124900000     Goldfinger
# 57    5.738034    6000000   245066411  The Godfather
# 65    5.738034    6000000   245066411  The Godfather
#
#                                                  cast  \
# 0   Kate Beckinsale|Scott Speedman|Michael Sheen|S...
# 29  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...
# 37  Sean Connery|Honor Blackman|Gert FrÃ¶be|Shirle...
# 57  Marlon Brando|Al Pacino|James Caan|Richard S. ...
# 65  Marlon Brando|Al Pacino|James Caan|Richard S. ...
#
#                                              homepage              director  \
# 0   http://www.sonypictures.com/movies/underworld/...           Len Wiseman
# 29              http://www.titanicmovie.com/menu.html         James Cameron
# 37      http://www.mgm.com/view/movie/760/Goldfinger/          Guy Hamilton
# ...

# %%
# Find the number of winners for high popularity
num_high_winners = winner_high_pop['winner'].count()
num_high_winners
# Out:
# 180

# %%
# Create Dataframe to hold winners with moderately high popularity level
winner_mod_high_pop = winner_df.loc[(winner_df['popularity_level'] == 'Moderately High')]
winner_mod_high_pop.head()
# Out:
#     popularity     budget    revenue     original_title  \
# 32    1.196636   70000000   69766619      The Brave One
# 41    1.910465   11000000  141195658        Thunderball
# 44    1.535278   30000000   33333531            The Box
# 45    2.100704   38000000  252276927          True Grit
# 66    1.714887  200000000  325233863  A Christmas Carol
#
#                                                  cast  \
# 32  Jodie Foster|Terrence Howard|Nicky Katt|Naveen...
# 41  Sean Connery|Claudine Auger|Adolfo Celi|Lucian...
# 44  Cameron Diaz|James Marsden|Frank Langella|Mich...
# 45  Jeff Bridges|Hailee Steinfeld|Matt Damon|Josh ...
# 66  Gary Oldman|Jim Carrey|Steve Valentine|Daryl S...
#
#                                              homepage              director  \
# 32                         http://www.thebraveone.com           Neil Jordan
# 41    http://www.mgm.com/view/movie/2009/Thunderball/         Terence Young
# ...

# %%
# Find the number of winners for moderately high popularity
num_mod_high_winners = winner_mod_high_pop['winner'].count()
num_mod_high_winners
# Out:
# 68

# %%
# Create Dataframe to hold winners with medium popularity level
winner_med_pop = winner_df.loc[(winner_df['popularity_level'] == 'Medium')]
winner_med_pop.head()
# Out:
#     popularity    budget    revenue      original_title  \
# 2     0.778440  40000000   58785180       Morning Glory
# 18    0.928134  55000000    9450897  All the King's Men
# 20    0.928134  55000000    9450897  All the King's Men
# 23    0.928134  55000000    9450897  All the King's Men
# 33    0.875247  80000000  123729176    The Time Machine
#
#                                                  cast  \
# 2   Rachel McAdams|Harrison Ford|Patrick Wilson|Je...
# 18  Sean Penn|Jude Law|Kate Winslet|James Gandolfi...
# 20  Sean Penn|Jude Law|Kate Winslet|James Gandolfi...
# 23  Sean Penn|Jude Law|Kate Winslet|James Gandolfi...
# 33  Guy Pearce|Samantha Mumba|Phyllida Law|Laura K...
#
#                                              homepage         director  \
# 2                   http://www.morningglorymovie.com/    Roger Michell
# 18  http://www.sonypictures.com/homevideo/alltheki...  Steven Zaillian
# 20  http://www.sonypictures.com/homevideo/alltheki...  Steven Zaillian
# ...

# %%
# Find the number of winners for medium popularity
num_med_winners = winner_med_pop['winner'].count()
num_med_winners
# Out:
# 27

# %%
# Create Dataframe to hold winners with low popularity level
winner_low_pop = winner_df.loc[(winner_df['popularity_level'] == 'Low')]
winner_low_pop.head()
# Out:
#      popularity    budget   revenue         original_title  \
# 11     0.414629   8000000    100915      Wuthering Heights
# 48     0.369308   1300000  29133000  The Last Picture Show
# 50     0.369308   1300000  29133000  The Last Picture Show
# 121    0.661178  40000000  45735397                 Arthur
# 127    0.661178  40000000  45735397                 Arthur
#
#                                                   cast  \
# 11   Kaya Scodelario|James Northcote|Amy Wren|Nicho...
# 48   Timothy Bottoms|Jeff Bridges|Cybill Shepherd|B...
# 50   Timothy Bottoms|Jeff Bridges|Cybill Shepherd|B...
# 121  Russell Brand|Helen Mirren|Greta Gerwig|Jennif...
# 127  Russell Brand|Helen Mirren|Greta Gerwig|Jennif...
#
#                                               homepage           director  \
# 11   http://www.artificial-eye.com/film.php?cinema=...      Andrea Arnold
# 48                  http://www.filmsite.org/lastp.html  Peter Bogdanovich
# ...

# %%
# Find the number of winners for low popularity
num_low_winners = winner_low_pop['winner'].count()
num_low_winners
# Out:
# 22

# %%
# Create a barchart to show the oscar winners by popularity level

# creating the dataset
data = {'High': num_high_winners, 'Moderately High': num_mod_high_winners, 'Medium ': num_med_winners,
        'Low': num_low_winners}

courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='darkolivegreen',
        width = 0.4)
 
plt.xlabel("Popularity Level ")
plt.ylabel("Number of Oscar Winners")
plt.title("Number of Oscar Winners by Popularity Level")
plt.show()


fig.savefig('../all movie analysis/winner_by_pop.png')  # save the figure to file
plt.close(fig)    # close the figure window

# %%
# Create a barchart displaying the non_oscar winners by popularity level

# %%
# Create dataframe to hold the non-winners
non_winner_df = clean_movie_df.loc[(clean_movie_df['winner']==False)]
non_winner_df.head()
# Out:
#    popularity    budget    revenue    original_title  \
# 1    0.477489   6000000   22231658              Emma
# 3    3.153414  90000000  589390539      Men in Black
# 4    0.883222  40000000   60474340  Marie Antoinette
# 5    0.883222  40000000   60474340  Marie Antoinette
# 6    0.883222  40000000   60474340  Marie Antoinette
#
#                                                 cast  \
# 1  Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 3  Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 4  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 5  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 6  Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
#
#                                             homepage          director  \
# 1                 http://www.miramax.com/movie/emma/   Douglas McGrath
# 3  http://www.sonypictures.com/homevideo/meninblack/  Barry Sonnenfeld
# 4  http://www.sonypictures.com/homevideo/marieant...     Sofia Coppola
# ...

# %%
# Create dataframe to hold nonwinners with a high popularity level
non_winner_high_pop = non_winner_df.loc[(non_winner_df['popularity_level'] == 'High')]
non_winner_high_pop.head()
# Out:
#     popularity     budget     revenue       original_title  \
# 3     3.153414   90000000   589390539         Men in Black
# 25    5.572950  200000000  1025467110  Alice in Wonderland
# 28    4.355219  200000000  1845034188              Titanic
# 43    3.789580  150000000   599045960        Casino Royale
# 58    5.738034    6000000   245066411        The Godfather
#
#                                                  cast  \
# 3   Tommy Lee Jones|Will Smith|Linda Fiorentino|Vi...
# 25  Mia Wasikowska|Johnny Depp|Anne Hathaway|Helen...
# 28  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...
# 43  Daniel Craig|Eva Green|Mads Mikkelsen|Judi Den...
# 58  Marlon Brando|Al Pacino|James Caan|Richard S. ...
#
#                                              homepage              director  \
# 3   http://www.sonypictures.com/homevideo/meninblack/      Barry Sonnenfeld
# 25                   http://disney.go.com/wonderland/            Tim Burton
# ...

# %%
# Find the number of nonwinners for high popularity
num_high_nonwinners = non_winner_high_pop['winner'].count()
num_high_nonwinners
# Out:
# 373

# %%
# Create Dataframe to hold nonwinners with moderately high popularity level
non_winner_mod_high_pop = non_winner_df.loc[(non_winner_df['popularity_level'] == 'Moderately High')]
non_winner_mod_high_pop.head()
# Out:
#     popularity    budget    revenue        original_title  \
# 17    1.407986  75000000  132274484  The Three Musketeers
# 26    1.412233  30000000   82394288                Carrie
# 27    1.412233  30000000   82394288                Carrie
# 30    1.196636  70000000   69766619         The Brave One
# 31    1.196636  70000000   69766619         The Brave One
#
#                                                  cast  \
# 17  Milla Jovovich|Orlando Bloom|Logan Lerman|Ray ...
# 26  ChloÃ« Grace Moretz|Julianne Moore|Judy Greer|...
# 27  ChloÃ« Grace Moretz|Julianne Moore|Judy Greer|...
# 30  Jodie Foster|Terrence Howard|Nicky Katt|Naveen...
# 31  Jodie Foster|Terrence Howard|Nicky Katt|Naveen...
#
#                                  homepage            director  \
# 17  http://www.threemusketeers-movie.com/  Paul W.S. Anderson
# 26            http://www.carrie-movie.com     Kimberly Peirce
# 27            http://www.carrie-movie.com     Kimberly Peirce
# ...

# %%
# Find the number of nonwinners for moderately high popularity
num_mod_high_nonwinners = non_winner_mod_high_pop['winner'].count()
num_mod_high_nonwinners
# Out:
# 193

# %%
# Create Dataframe to hold nonwinners with medium popularity level
non_winner_med_pop = non_winner_df.loc[(non_winner_df['popularity_level'] == 'Medium')]
non_winner_med_pop.head()
# Out:
#     popularity    budget   revenue        original_title  \
# 4     0.883222  40000000  60474340      Marie Antoinette
# 5     0.883222  40000000  60474340      Marie Antoinette
# 6     0.883222  40000000  60474340      Marie Antoinette
# 7     0.883222  40000000  60474340      Marie Antoinette
# 16    0.794564  30000000  53898845  The Three Musketeers
#
#                                                  cast  \
# 4   Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 5   Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 6   Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 7   Kirsten Dunst|Jason Schwartzman|Judy Davis|Rip...
# 16  Charlie Sheen|Kiefer Sutherland|Chris O'Donnel...
#
#                                              homepage       director  \
# 4   http://www.sonypictures.com/homevideo/marieant...  Sofia Coppola
# 5   http://www.sonypictures.com/homevideo/marieant...  Sofia Coppola
# 6   http://www.sonypictures.com/homevideo/marieant...  Sofia Coppola
# ...

# %%
# Find the number of nonwinners for medium popularity
num_med_nonwinners = non_winner_med_pop['winner'].count()
num_med_nonwinners
# Out:
# 124

# %%
# Create Dataframe to hold nonwinners with low popularity level
non_winner_low_pop = non_winner_df.loc[(non_winner_df['popularity_level'] == 'Low')]
non_winner_low_pop.head()
# Out:
#     popularity   budget   revenue     original_title  \
# 1     0.477489  6000000  22231658               Emma
# 8     0.414629  8000000    100915  Wuthering Heights
# 9     0.414629  8000000    100915  Wuthering Heights
# 10    0.414629  8000000    100915  Wuthering Heights
# 12    0.414629  8000000    100915  Wuthering Heights
#
#                                                  cast  \
# 1   Gwyneth Paltrow|Toni Collette|Alan Cumming|Ewa...
# 8   Kaya Scodelario|James Northcote|Amy Wren|Nicho...
# 9   Kaya Scodelario|James Northcote|Amy Wren|Nicho...
# 10  Kaya Scodelario|James Northcote|Amy Wren|Nicho...
# 12  Kaya Scodelario|James Northcote|Amy Wren|Nicho...
#
#                                              homepage         director  \
# 1                  http://www.miramax.com/movie/emma/  Douglas McGrath
# 8   http://www.artificial-eye.com/film.php?cinema=...    Andrea Arnold
# 9   http://www.artificial-eye.com/film.php?cinema=...    Andrea Arnold
# ...

# %%
# Find the number of nonwinners for low popularity
num_low_nonwinners = non_winner_low_pop['winner'].count()
num_low_nonwinners
# Out:
# 121

# %%
# Create a barchart to show the non-oscar winners by popularity level

# creating the dataset
data = {'High': num_high_nonwinners, 'Moderately High': num_mod_high_nonwinners, 'Medium ': num_med_nonwinners,
        'Low': num_low_nonwinners}

courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='yellowgreen',
        width = 0.4)
 
plt.xlabel("Popularity Level ")
plt.ylabel("Number of Non-Oscar Winners")
plt.title("Number of Non-Oscar Winners by Popularity Level")
plt.show()


fig.savefig('../all movie analysis/non_winner_by_pop.png')  # save the figure to file
plt.close(fig)    # close the figure window
