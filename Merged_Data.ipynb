# %%
# Import dependecies
import pandas as pd
import numpy as np

# %%
# Import data for pre-processing
production_df = pd.read_csv('../data.csv')
df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
production_df['release_date'] = pd.to_datetime(production_df['release_date'])
production_df['release_date'][:10]
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# 5   2015-12-25
# 6   2015-06-23
# 7   2015-09-30
# 8   2015-06-17
# 9   2015-06-09
# Name: release_date, dtype: datetime64[ns]

# %%
production_df['release_year'] = production_df['release_date'].dt.year
production_df['release_year']
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 10861    1966
# 10862    1966
# 10863    1966
# 10864    1966
# 10865    1966
# Name: release_year, Length: 10866, dtype: int64

# %%
production_df = production_df.loc[(production_df['release_year'] >= 1961) & (df['release_year'] <= 2015)]
production_df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
production_df.shape
# Out:
# (10834, 21)

# %%
production_df = production_df.drop_duplicates(subset=['original_title'], keep='first')
production_df.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %%
production_df['film'] = production_df['original_title']
production_df['film']
# Out:
# 0                      Jurassic World
# 1                  Mad Max: Fury Road
# 2                           Insurgent
# 3        Star Wars: The Force Awakens
# 4                           Furious 7
#                      ...
# 10861              The Endless Summer
# 10862                      Grand Prix
# 10863             Beregis Avtomobilya
# 10864          What's Up, Tiger Lily?
# 10865        Manos: The Hands of Fate
# Name: film, Length: 10546, dtype: object

# %%
production_df = production_df.drop(['original_title'], axis = 1)

# %%
production_df.shape
# Out:
# (10546, 21)

# %%
oscars_df = pd.read_csv('the_oscar_award.csv')
oscars_df.head(10)
# Out:
#    year_film  year_ceremony  ceremony        category  \
# 0       1927           1928         1           ACTOR
# 1       1927           1928         1           ACTOR
# 2       1927           1928         1         ACTRESS
# 3       1927           1928         1         ACTRESS
# 4       1927           1928         1         ACTRESS
# 5       1927           1928         1   ART DIRECTION
# 6       1927           1928         1   ART DIRECTION
# 7       1927           1928         1   ART DIRECTION
# 8       1927           1928         1  CINEMATOGRAPHY
# 9       1927           1928         1  CINEMATOGRAPHY
#
#                       name               film winner
# 0      Richard Barthelmess          The Noose  False
# 1            Emil Jannings   The Last Command   True
# 2           Louise Dresser    A Ship Comes In  False
# 3             Janet Gaynor         7th Heaven   True
# 4           Gloria Swanson     Sadie Thompson  False
# ...

# %%
oscars_df = oscars_df.loc[(oscars_df['year_film'] >= 1961) & (oscars_df['year_film'] < 2016)]
oscars_df.head(10)
# Out:
#       year_film  year_ceremony  ceremony                    category  \
# 3714       1961           1962        34                       ACTOR
# 3715       1961           1962        34                       ACTOR
# 3716       1961           1962        34                       ACTOR
# 3717       1961           1962        34                       ACTOR
# 3718       1961           1962        34                       ACTOR
# 3719       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3720       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3721       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3722       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3723       1961           1962        34  ACTOR IN A SUPPORTING ROLE
#
#                    name                   film winner
# 3714      Charles Boyer                  Fanny  False
# 3715        Paul Newman            The Hustler  False
# ...

# %%
oscars_df.shape
# Out:
# (6175, 7)

# %%
oscars_df = oscars_df.drop_duplicates(subset=['film'], keep='first')
oscars_df.head(10)
# Out:
#       year_film  year_ceremony  ceremony                    category  \
# 3714       1961           1962        34                       ACTOR
# 3715       1961           1962        34                       ACTOR
# 3716       1961           1962        34                       ACTOR
# 3718       1961           1962        34                       ACTOR
# 3719       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3721       1961           1962        34  ACTOR IN A SUPPORTING ROLE
# 3724       1961           1962        34                     ACTRESS
# 3726       1961           1962        34                     ACTRESS
# 3727       1961           1962        34                     ACTRESS
# 3728       1961           1962        34                     ACTRESS
#
#                    name                    film winner
# 3714      Charles Boyer                   Fanny  False
# 3715        Paul Newman             The Hustler  False
# ...

# %%
oscars_df.shape
# Out:
# (2871, 7)

# %%
merged_df = production_df.merge(oscars_df, on='film', how='outer')
merged_df.head(10)
# Out:
#          id    imdb_id  popularity       budget       revenue  \
# 0  135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1   76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2  262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3  140607.0  tt2488496   11.173104  200000000.0  2.068178e+09
# 4  168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
# 5  281957.0  tt1663202    9.110700  135000000.0  5.329505e+08
# 6   87101.0  tt1340138    8.654359  155000000.0  4.406035e+08
# 7  286217.0  tt3659388    7.667400  108000000.0  5.953803e+08
# 8  211672.0  tt2293640    7.404165   74000000.0  1.156731e+09
# 9  150540.0  tt2096673    6.326804  175000000.0  8.537086e+08
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# ...

# %%
merged_df.shape
# Out:
# (12116, 27)

# %%
merged_df.head(10)
# Out:
#          id    imdb_id  popularity       budget       revenue  \
# 0  135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1   76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2  262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3  140607.0  tt2488496   11.173104  200000000.0  2.068178e+09
# 4  168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
# 5  281957.0  tt1663202    9.110700  135000000.0  5.329505e+08
# 6   87101.0  tt1340138    8.654359  155000000.0  4.406035e+08
# 7  286217.0  tt3659388    7.667400  108000000.0  5.953803e+08
# 8  211672.0  tt2293640    7.404165   74000000.0  1.156731e+09
# 9  150540.0  tt2096673    6.326804  175000000.0  8.537086e+08
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# ...

# %%
merged_df.tail(30)
# Out:
#        id imdb_id  popularity  budget  revenue cast homepage director tagline  \
# 12086 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12087 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12088 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12089 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12090 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12091 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12092 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12093 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12094 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12095 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# 12096 NaN     NaN         NaN     NaN      NaN  NaN      NaN      NaN     NaN
# ...

# %%
duplicates = merged_df.duplicated(subset='film')
num_duplicates = duplicates.sum()
print(f"There are {num_duplicates} duplicates in the merged dataframe.")
# Out:
# There are 0 duplicates in the merged dataframe.

# %%
merged_df.to_csv('merged_dataframe.csv', index=False)
